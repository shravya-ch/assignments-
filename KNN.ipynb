# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\home\\Downloads\\bank-additional.csv',sep = ';')

# %%
data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
# age               4119 non-null int64
# job               4119 non-null object
# marital           4119 non-null object
# education         4119 non-null object
# default           4119 non-null object
# housing           4119 non-null object
# loan              4119 non-null object
# contact           4119 non-null object
# month             4119 non-null object
# day_of_week       4119 non-null object
# duration          4119 non-null int64
# campaign          4119 non-null int64
# pdays             4119 non-null int64
# previous          4119 non-null int64
# poutcome          4119 non-null object
# emp.var.rate      4119 non-null float64
# cons.price.idx    4119 non-null float64
# cons.conf.idx     4119 non-null float64
# euribor3m         4119 non-null float64
# nr.employed       4119 non-null float64
# y                 4119 non-null object
# ...

# %%
data.shape
# Out:
# (4119, 21)

# %%
data.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
data.columns
# Out:
# Index([u'age', u'job', u'marital', u'education', u'default', u'housing',
#        u'loan', u'contact', u'month', u'day_of_week', u'duration', u'campaign',
#        u'pdays', u'previous', u'poutcome', u'emp.var.rate', u'cons.price.idx',
#        u'cons.conf.idx', u'euribor3m', u'nr.employed', u'y'],
#       dtype='object')

# %%
data.isnull().any()
# Out:
# age               False
# job               False
# marital           False
# education         False
# default           False
# housing           False
# loan              False
# contact           False
# month             False
# day_of_week       False
# duration          False
# campaign          False
# pdays             False
# previous          False
# poutcome          False
# emp.var.rate      False
# cons.price.idx    False
# cons.conf.idx     False
# euribor3m         False
# nr.employed       False
# y                 False
# dtype: bool

# %%
data['outcome'] = data.y.map({'no' : 0 ,'yes' : 1})
data.shape
# Out:
# (4119, 22)

# %%
data['outcome'].value_counts()
# Out:
# 0    3668
# 1     451
# Name: outcome, dtype: int64

# %%
count_no = 0 
count_yes = 0
for i in (data.outcome) :
    if i == 0 :
        count_no = count_no + 1
    else :
        count_yes = count_yes + 1
        
print count_no , count_yes
# Out:
# 3668 451

# %%
columns = ['age', 'duration', 'campaign','pdays', 'previous', 'emp.var.rate', 'cons.price.idx','cons.conf.idx', 'euribor3m', 
           'nr.employed']
for column in columns:
    x = columns.index(column)
    x = x+1 
    plt.subplot(10,1,x)
    plt.boxplot(data[column])

# %%
plt.boxplot(data['nr.employed'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xacb4a90>],
#  'caps': [<matplotlib.lines.Line2D at 0xad90208>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xad90be0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xad90898>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xacb4b38>,
#   <matplotlib.lines.Line2D at 0xacb4e80>]}

# %%
yes = (data[data.outcome == 1 ])
x = (data[data.outcome == 0 ])
#print y.shape , x.shape
plt.hist (yes.age)
# Out:
# (array([ 12., 104., 108.,  70.,  52.,  56.,  23.,   9.,   8.,   9.]),
#  array([18. , 24.8, 31.6, 38.4, 45.2, 52. , 58.8, 65.6, 72.4, 79.2, 86. ]),
#  <a list of 10 Patch objects>)

# %%
pd.crosstab(data.job,data.y,margins=True)
# Out:
# y                no  yes   All
# job
# admin.          879  133  1012
# blue-collar     823   61   884
# entrepreneur    140    8   148
# housemaid        99   11   110
# management      294   30   324
# retired         128   38   166
# self-employed   146   13   159
# services        358   35   393
# student          63   19    82
# technician      611   80   691
# unemployed       92   19   111
# unknown          35    4    39
# All            3668  451  4119

# %%
data.groupby(['age']).size().plot()

# %%
data['age_bins']= data.groupby(['age']).size().plot()#y	no	yes#age_bins

# %%
pd.crosstab(data.age_bins,data.y).apply(lambda r: r/r.sum(), axis=1)
# Out:
# y                                           no       yes
# age_bins
# AxesSubplot(0.125,0.125;0.775x0.755)  0.890507  0.109493

# %%
dfByEdu=pd.crosstab(data.education,data.y).apply(lambda r: r/r.sum(), axis=1)
dfByEdu['yes'].plot(kind='bar')

# %%
frst age and then job and do column wise

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 

data = pd.read_csv('C://Users//home//Downloads//loan_data_set.csv')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
# Gender               614 non-null category
# Married              614 non-null category
# Dependents           614 non-null category
# Education            614 non-null category
# Self_Employed        614 non-null category
# ApplicantIncome      614 non-null float64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     614 non-null float64
# Credit_History       614 non-null category
# Property_Area        614 non-null category
# Loan_Status          614 non-null category
# dtypes: category(8), float64(4)
# memory usage: 25.0 KB

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
for col in data.select_dtypes('object'):
    data[col] = data[col].astype('category')

# %%
data['Credit_History'] = data['Credit_History'].astype('category')

# %%
data.isnull().sum().plot(kind ='bar')
plt.show()

# %%
data = data.drop('Loan_ID',axis = 1)

# %%
data.shape
# Out:
# (614, 12)

# %%
cat_cols = [ col for col in list(data.select_dtypes('category').columns)]
cat_cols
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
num_cols = [col for col in list(data.select_dtypes(['int64','float64']).columns)]
num_cols
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
data[cat_cols] = data[cat_cols].apply(lambda x: x.fillna(x.value_counts().index[0]))

# %%
data[cat_cols].isnull().sum()
# Out:
# Gender            0
# Married           0
# Dependents        0
# Education         0
# Self_Employed     0
# Credit_History    0
# Property_Area     0
# Loan_Status       0
# dtype: int64

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp_mean = IterativeImputer(random_state=0)
data[num_cols] = pd.DataFrame(imp_mean.fit_transform(data[num_cols]),columns = num_cols)

# %%
data[num_cols].isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# dtype: int64

# %%
fig = plt.figure(figsize=(20,20))
i = 1
for col in num_cols:
    plt.subplot(5,2,i)
    sns.boxplot(data['Loan_Status'],data.loc[:,col])
    i=i+1
plt.tight_layout()
plt.show()

# %%
plt.pie(data['Loan_Status'].value_counts(),labels= data['Loan_Status'].value_counts().index.tolist(),autopct='%.2f')
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
i = 1
for col in num_cols:
    plt.subplot(5,2,i)
    sns.distplot(data[col],kde= False)
    i=i+1
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
i = 1
for col in cat_cols:
    plt.subplot(5,2,i)
    sns.countplot(data[col])
    i=i+1
plt.tight_layout()
plt.show()

# %%
cols
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Credit_History',
#  'Property_Area']

# %%
# %matplotlib inline
fig,axs = plt.subplots(4,2,figsize=(25,25))
axs=axs.flatten()
axs[-1].axis('off')
for col,ind in zip(cols,range(len(cols))):
    pd.crosstab(data[col],data['Loan_Status']).plot(kind='bar',rot= 45,ax=axs[ind])

plt.tight_layout()

# %%
sns.set(style='white')

corr = data.corr()
mask = np.zeros_like(corr,dtype=bool)
mask[np.triu_indices_from(mask)] = True
cmap = sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(corr,mask=mask,cmap=cmap,annot=True)
plt.show()

# %%
labels = pd.crosstab(data['Education'],data['Loan_Status']).index.tolist()
x = np.arange(len(labels))
width = 0.35
rects1 = plt.bar(x - width/2,pd.crosstab(data['Education'],data['Loan_Status']).iloc[:,0] , width, label=pd.crosstab(data['Education'],data['Loan_Status']).columns[0])
rects2 = plt.bar(x + width/2, pd.crosstab(data['Education'],data['Loan_Status']).iloc[:,1], width, label=pd.crosstab(data['Education'],data['Loan_Status']).columns[1])
plt.xlabel(pd.crosstab(data['Education'],data['Loan_Status']).index.tolist())
plt.tight_layout()
plt.legend()
plt.show()

# %%
data['Loan_Status'] = data['Loan_Status'].apply(lambda x:1 if x=='Y' else 0)
data['Loan_Status'] = data['Loan_Status'].astype('int64')
fig = plt.figure(figsize=(20,20))
i=1
for cols in data[cat_cols]:
    plt.subplot(4,2,i)
    sns.barplot(x=cols, y='Loan_Status',data=data);
    plt.title('Loan Status by {}'.format(cols))
    i=i+1
    
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# target column
tgt_col = ['Loan_Status']

# Categorical cols
category_names = data.nunique()[data.nunique() < 15].keys().tolist()
category_names = [x for x in category_names if x not in tgt_col]

# Numerical cols
num_cols = [i for i in data.columns if i not in category_names + tgt_col]

# Binary cols
bin_cols = data.nunique()[data.nunique()==2].keys().tolist()

# Multi-cols
multi_cols = [i for i in category_names if i not in bin_cols]

# Label Encoding Binary cols
le = LabelEncoder()
for i in bin_cols:
    data[i] = le.fit_transform(data[i])
    
# Duplicating cols for multi-value columns
data = pd.get_dummies(data=data, columns=multi_cols)

# %%
cont_features = []
for features in data.select_dtypes(include=['int64','float64']):
    if features != 'Loan_Status':
        cont_features.append(features)

# %%
ld_df = data
# Scaling numerical features
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
ld_df[cont_features] = minmax.fit_transform(ld_df[cont_features].values)

# %%
cols = [i for i in ld_df.columns if i not in tgt_col]
X = ld_df[cols]
Y = pd.DataFrame(ld_df['Loan_Status'])

# %%
from sklearn.model_selection import StratifiedKFold

# %%
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
for train_index, test_index in folds.split(X,Y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

# %%
from sklearn.neighbors import KNeighborsClassifier

# Setup arrays to store training and test accuracies
neighbors = np.arange(1,9)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    
    # Fit the model
    knn.fit(X_train, Y_train)
    
    # Compute accuracy on the training set
    train_accuracy[i] = knn.score(X_train, Y_train)
    
    # Compute accuracy on test set
    test_accuracy[i] = knn.score(X_test, Y_test)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':
# ...

# %%
plt.title('K-NN Varying number of neighbors')
plt.plot(neighbors, test_accuracy, label='Testing Accuracy')
plt.plot(neighbors, train_accuracy, label='Training Accuracy')
plt.legend()
plt.xlabel('Number of neighbors')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=5)
# Fit the model
knn.fit(X_train, Y_train)
# Getting accuracy
knn.score(X_test, Y_test)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.7540983606557377

# %%
from sklearn.metrics import confusion_matrix
#let us get the predictions using the classifier we had fit above
Y_pred = knn.predict(X_test)
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[11, 27],
#        [ 3, 81]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.29      0.42        38
#            1       0.75      0.96      0.84        84
#
#     accuracy                           0.75       122
#    macro avg       0.77      0.63      0.63       122
# weighted avg       0.76      0.75      0.71       122

# %%
Y_pred_proba = knn.predict_proba(X_test)[:,1]
from sklearn.metrics import roc_curve
fpr, tpr, thresholds  = roc_curve(Y_test, Y_pred_proba)

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='knn')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('Knn(n_neighbors=5) ROC Curve')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(Y_test, Y_pred_proba)
# Out:
# 0.7911967418546366

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors':np.arange(1,50)}
knn=KNeighborsClassifier()
knn_cv = GridSearchCV(knn, param_grid, cv=5)
knn_cv.fit(X,Y)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
knn_cv.best_score_
# Out:
# 0.7491270158603226

# %%
knn_cv.best_params_
# Out:
# {'n_neighbors': 16}
